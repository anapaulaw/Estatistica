# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.read_excel('PESQUISA_ALUNOS.xlsx')

# %%
df
# Out:
#                        DATA    IDADE       SEXO  \
# 0   2023-10-04 08:28:24.051       15  Masculino
# 1   2023-10-04 08:36:21.587       16  Masculino
# 2   2023-10-04 08:38:36.021       18   Feminino
# 3   2023-10-04 08:49:27.006       20  Masculino
# 4   2023-10-04 08:55:14.370       17  Masculino
# ..                      ...      ...        ...
# 877 2023-10-04 23:34:24.885       20   Feminino
# 878 2023-10-05 01:22:18.394       57  Masculino
# 879 2023-10-05 02:24:21.578       40   Feminino
# 880 2023-10-05 07:18:15.579       18   Feminino
# 881 2023-10-05 07:51:47.052  26 anos   Feminino
#
#     QUANTAS PESSOAS MORAM COM VOCÊ                 RENDA/FAMILIA  \
# 0                        5 ou mais          Até 1 salário mínimo
# 1                        5 ou mais         Prefiro não responder
# 2                                3    De 7 a 10 salários mínimos
# 3                                4     De 3 a 6 salários mínimos
# 4                                2         Prefiro não responder
# ..                             ...                           ...
# 877                              4     De 1 a 2 salários mínimos
# 878                      5 ou mais  Acima de 10 salários mínimos
# 879                      5 ou mais     De 1 a 2 salários mínimos
# 880                              4     De 3 a 6 salários mínimos
# 881                              2          Até 1 salário mínimo
#
#                     ESCOLARIDADE/PAIS  ESTADO CIVIL QUANTOS FILHOS TRABALHA  \
# 0          Nível Médio (1º ao 3º ano)  Solteiro (a)              0      Não
# 1          Nível Médio (1º ao 3º ano)  Solteiro (a)              0      Não
# 2          Nível Médio (1º ao 3º ano)  Solteiro (a)              0      Não
# 3    Nível Fundamental (1º ao 9º ano)  Solteiro (a)              0      Não
# 4                   Não sei responder  Solteiro (a)              0      Sim
# ..                                ...           ...            ...      ...
# 877                    Nível superior  Solteiro (a)              0      Sim
# 878  Nível Fundamental (1º ao 9º ano)    Casado (a)              4      Sim
# 879  Nível Fundamental (1º ao 9º ano)    Casado (a)      5 ou mais      Sim
# 880        Nível Médio (1º ao 3º ano)  Solteiro (a)              0      Não
# 881                 Não sei responder    Casado (a)              1      Sim
#
#        RAÇA TIPO DE ESCOLA                                 CURSO DE INTERESSE  \
# 0     Parda        Pública                      Faculdade de Engenharia Civil
# 1     Preta        Pública                       Faculdade de Educação Física
# 2    Branca     Particular                               Faculdade de Direito
# 3    Branca     Particular  Faculdade de Psicologia, Faculdade de Administ...
# 4    Branca        Pública                 Faculdade de Ciência Da Computação
# ..      ...            ...                                                ...
# 877   Parda        Pública                       Faculdade de Educação Física
# 878  Branca     Particular                                            Não sei
# 879   Preta         Outros                              Faculdade de Nutrição
# 880  Branca        Pública                         Faculdade de Administração
# 881   Preta         Outros                                            Não sei
#
#        TURNO INTERESSE GASTO COM INTERNET DIÁRIO  \
# 0           Vespertino            De 3 a 4 horas
# 1           Vespertino            De 3 a 4 horas
# 2             Matutino            De 2 a 3 horas
# 3             Matutino           Mais de 4 horas
# 4              Noturno            De 2 a 3 horas
# ..                 ...                       ...
# 877           Matutino            De 1 a 2 horas
# 878  EaD (à distância)            De 2 a 3 horas
# 879           Matutino           Mais de 4 horas
# 880           Matutino            De 1 a 2 horas
# 881  EaD (à distância)           Mais de 4 horas
#
#     VOCÊ ESTUDARIA NESSA FACULDADE
# 0                              Não
# 1                           Talvez
# 2                              Sim
# 3                              Sim
# 4                              Não
# ..                             ...
# 877                            Sim
# 878                            Sim
# 879                            Sim
# 880                            Não
# 881                         Talvez
#
# [882 rows x 15 columns]

# %% [markdown]
# ## ANÁLISE DOS DADOS
#
# ---

# %%
df.shape
print(f"Total de registros: {df.shape[0]}")
print(f"Total de variáveis: {df.shape[1]}")
# Out:
# Total de registros: 882
# Total de variáveis: 15

# %%
list(df)
# Out:
# ['DATA',
#  'IDADE',
#  'SEXO',
#  'QUANTAS PESSOAS MORAM COM VOCÊ',
#  'RENDA/FAMILIA',
#  'ESCOLARIDADE/PAIS',
#  'ESTADO CIVIL',
#  'QUANTOS FILHOS',
#  'TRABALHA',
#  'RAÇA',
#  'TIPO DE ESCOLA',
#  'CURSO DE INTERESSE',
#  'TURNO INTERESSE',
#  'GASTO COM INTERNET DIÁRIO',
#  'VOCÊ ESTUDARIA NESSA FACULDADE']

# %% [markdown]
# MEDIDAS DESCRITIVAS
#
# ---

# %%
variaveis_categoricas = df.select_dtypes(include='object').columns.tolist()

# Loop sobre as variáveis categóricas para calcular medidas descritivas
for variavel in variaveis_categoricas:
    print(f'\nEstatísticas Descritivas para {variavel}:')
    print(df[variavel].describe())
# Out:
# Estatísticas Descritivas para SEXO:
# count          882
# unique           4
# top       Feminino
# freq           508
# Name: SEXO, dtype: object
#
# Estatísticas Descritivas para QUANTAS PESSOAS MORAM COM VOCÊ:
# count     882
# unique      6
# top         3
# freq      256
# Name: QUANTAS PESSOAS MORAM COM VOCÊ, dtype: int64
#
# Estatísticas Descritivas para RENDA/FAMILIA:
# count                           882
# unique                            6
# top       De 1 a 2 salários mínimos
# freq                            330
# Name: RENDA/FAMILIA, dtype: object
#
# Estatísticas Descritivas para ESCOLARIDADE/PAIS:
# count                            882
# unique                             5
# top       Nível Médio (1º ao 3º ano)
# freq                             383
# Name: ESCOLARIDADE/PAIS, dtype: object
#
# Estatísticas Descritivas para ESTADO CIVIL:
# count              882
# unique               4
# top       Solteiro (a)
# freq               843
# Name: ESTADO CIVIL, dtype: object
#
# Estatísticas Descritivas para QUANTOS FILHOS:
# count     882
# unique      6
# top         0
# freq      827
# Name: QUANTOS FILHOS, dtype: int64
#
# Estatísticas Descritivas para TRABALHA:
# count     882
# unique      2
# top       Não
# freq      540
# Name: TRABALHA, dtype: object
#
# Estatísticas Descritivas para RAÇA:
# count        882
# unique         5
# top       Branca
# freq         353
# Name: RAÇA, dtype: object
#
# Estatísticas Descritivas para TIPO DE ESCOLA:
# count         882
# unique          3
# top       Pública
# freq          754
# Name: TIPO DE ESCOLA, dtype: object
#
# Estatísticas Descritivas para CURSO DE INTERESSE:
# count       880
# unique      242
# top       Outro
# freq        103
# Name: CURSO DE INTERESSE, dtype: object
#
# Estatísticas Descritivas para TURNO INTERESSE:
# count          882
# unique           4
# top       Matutino
# freq           518
# Name: TURNO INTERESSE, dtype: object
#
# Estatísticas Descritivas para GASTO COM INTERNET DIÁRIO:
# count                 882
# unique                  5
# top       Mais de 4 horas
# freq                  411
# Name: GASTO COM INTERNET DIÁRIO, dtype: object
#
# Estatísticas Descritivas para VOCÊ ESTUDARIA NESSA FACULDADE:
# count     882
# unique      3
# top       Sim
# freq      617
# Name: VOCÊ ESTUDARIA NESSA FACULDADE, dtype: object

# %% [markdown]
# COMPLETUDE DA BASE
#
# ---

# %%
completude = df.count()
percentual_completude = (completude / len(df)) * 100

resultados = pd.DataFrame({'Completude': completude, 'Percentual de Completude': percentual_completude})
resultados
# Out:
#                                 Completude  Percentual de Completude
# DATA                                   882                100.000000
# IDADE                                  882                100.000000
# SEXO                                   882                100.000000
# QUANTAS PESSOAS MORAM COM VOCÊ         882                100.000000
# RENDA/FAMILIA                          882                100.000000
# ESCOLARIDADE/PAIS                      882                100.000000
# ESTADO CIVIL                           882                100.000000
# QUANTOS FILHOS                         882                100.000000
# TRABALHA                               882                100.000000
# RAÇA                                   882                100.000000
# TIPO DE ESCOLA                         882                100.000000
# CURSO DE INTERESSE                     880                 99.773243
# TURNO INTERESSE                        882                100.000000
# GASTO COM INTERNET DIÁRIO              882                100.000000
# VOCÊ ESTUDARIA NESSA FACULDADE         882                100.000000

# %% [markdown]
# CONSULTANDO AS CATEGORIAS ÚNICAS DE CADA VARIÁVEL
#
# ---

# %%
variaveis = ['SEXO', 'QUANTAS PESSOAS MORAM COM VOCÊ', 'RENDA/FAMILIA', 'ESCOLARIDADE/PAIS', 'ESTADO CIVIL',
             'QUANTOS FILHOS', 'TRABALHA', 'RAÇA', 'TIPO DE ESCOLA', 'CURSO DE INTERESSE', 'TURNO INTERESSE',
             'GASTO COM INTERNET DIÁRIO', 'VOCÊ ESTUDARIA NESSA FACULDADE']

# %%
for variavel in variaveis:
    if variavel in df.columns:
        categorias_unicas = df[variavel].unique()
        print(f'Variável: {variavel}')
        print(f'Categorias Únicas: {categorias_unicas}')
        print('\n')
    else:
        print(f'Variável {variavel} não encontrada no DataFrame.')
# Out:
# Variável: SEXO
# Categorias Únicas: ['Masculino' 'Feminino' 'Prefiro não dizer' 'Outro']
#
#
# Variável: QUANTAS PESSOAS MORAM COM VOCÊ
# Categorias Únicas: ['5 ou mais' 3 4 2 1 0]
#
#
# Variável: RENDA/FAMILIA
# Categorias Únicas: ['Até 1 salário mínimo' 'Prefiro não responder'
#  'De 7 a 10 salários mínimos' 'De 3 a 6 salários mínimos'
#  'De 1 a 2 salários mínimos' 'Acima de 10 salários mínimos']
#
#
# Variável: ESCOLARIDADE/PAIS
# Categorias Únicas: ['Nível Médio (1º ao 3º ano)' 'Nível Fundamental (1º ao 9º ano)'
#  'Não sei responder' 'Nível superior' 'Analfabeto']
#
#
# Variável: ESTADO CIVIL
# Categorias Únicas: ['Solteiro (a)' 'Casado (a)' 'Divorciado (a)' 'Viúvo (a)']
#
#
# Variável: QUANTOS FILHOS
# Categorias Únicas: [0 3 2 1 4 '5 ou mais']
#
#
# Variável: TRABALHA
# Categorias Únicas: ['Não' 'Sim']
#
#
# Variável: RAÇA
# Categorias Únicas: ['Parda' 'Preta' 'Branca' 'Indígena' 'Amarela']
#
#
# Variável: TIPO DE ESCOLA
# Categorias Únicas: ['Pública' 'Particular' 'Outros']
#
#
# Variável: CURSO DE INTERESSE
# Categorias Únicas: ['Faculdade de Engenharia Civil' 'Faculdade de Educação Física'
#  'Faculdade de Direito'
#  'Faculdade de Psicologia, Faculdade de Administração, Faculdade de Ciências Econômicas, Faculdade de Ciência Da Computação'
#  'Faculdade de Ciência Da Computação'
#  'Faculdade de Psicologia, Faculdade de Administração'
#  'Faculdade de Educação Física, Gestão da Tecnologia da Informação, Análise e Desenvolvimento de Sistemas'
#  'Faculdade de Pedagogia, Faculdade de Educação Física, Curso de Gastronomia, Faculdade de Publicidade e Propaganda, Faculdade de Jornalismo, Curso de Design Gráfico'
#  'Faculdade de Veterinária, Faculdade de Direito' 'Outro'
#  'Gestão da Tecnologia da Informação' 'Faculdade de Ciências Econômicas'
#  'Faculdade de Odontologia' 'Análise e Desenvolvimento de Sistemas'
#  'Faculdade de Pedagogia, Curso de Design Gráfico'
#  'Faculdade de Veterinária'
#  'Faculdade de Odontologia, Faculdade de Fisioterapia'
#  'Faculdade de Administração' 'Não sei'
#  'Faculdade de Fisioterapia, Faculdade de Nutrição'
#  'Faculdade de Enfermagem'
#  'Faculdade de Nutrição, Faculdade de Educação Física, Outro'
#  'Faculdade de Psicologia, Faculdade de Pedagogia, Faculdade de Letras, Faculdade de Educação Física, Faculdade de Administração, Curso de Gestão Pública'
#  'Faculdade de Jornalismo' 'Faculdade de Psicologia'
#  'Curso de Design Gráfico'
#  'Faculdade de Odontologia, Faculdade de Veterinária'
#  'Curso de Design Gráfico, Gestão da Tecnologia da Informação, Análise e Desenvolvimento de Sistemas, Faculdade de Ciência Da Computação, Faculdade de Sistema de Informação'
#  'Faculdade de Veterinária, Faculdade de Psicologia'
#  'Faculdade de Enfermagem, Faculdade de Fisioterapia, Faculdade de Nutrição, Faculdade de Biomedicina'
#  'Faculdade de Psicologia, Faculdade de Fisioterapia'
#  'Curso de Gastronomia, Faculdade de Jogos Digitais, Faculdade de Engenharia Mecatrônica'
#  'Faculdade de Nutrição, Faculdade de Educação Física'
#  'Faculdade de Biomedicina, Outro'
#  'Faculdade de Veterinária, Faculdade de Enfermagem, Faculdade de Educação Física'
#  'Faculdade de Nutrição'
#  'Faculdade de Ciências Biológicas, Faculdade de Pedagogia, Faculdade de Educação Física'
#  'Faculdade de Ciências Contábeis'
#  'Faculdade de Ciências Contábeis, Curso de Gastronomia, Gestão da Tecnologia da Informação'
#  'Faculdade de Direito, Faculdade de Ciências Contábeis'
#  'Faculdade de Enfermagem, Faculdade de Nutrição, Faculdade de Engenharia Ambiental'
#  'Faculdade de Veterinária, Faculdade de Administração'
#  'Faculdade de Fisioterapia, Não sei' 'Faculdade de Engenharia Ambiental'
#  'Faculdade de Pedagogia, Faculdade de Educação Física'
#  'Faculdade de Ciências Biológicas, Faculdade de Jornalismo'
#  'Faculdade de Psicologia, Faculdade de Administração, Curso de Design de Produto, Faculdade de Jornalismo'
#  'Faculdade de Odontologia, Faculdade de Nutrição']
#
#
# Variável: TURNO INTERESSE
# Categorias Únicas: ['Vespertino' 'Matutino' 'Noturno' 'EaD (à distância)']
#
#
# Variável: GASTO COM INTERNET DIÁRIO
# Categorias Únicas: ['De 3 a 4 horas' 'De 2 a 3 horas' 'Mais de 4 horas' 'De 1 a 2 horas'
#  'Até 1 hora']
#
#
# Variável: VOCÊ ESTUDARIA NESSA FACULDADE
# Categorias Únicas: ['Não' 'Talvez' 'Sim']

# %% [markdown]
# #VISUALIZAÇÃO
#
# ---

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
variaveis = [variavel for variavel in variaveis if variavel != ['IDADE' , 'CURSO DE INTERESSE']]


for variavel in variaveis:
    print(f'\nVariável: {variavel}')
    print(f'Categorias Únicas: {df[variavel].unique()}')
    print(f'Tabela de Frequência:\n{df[variavel].value_counts(dropna=False)}\n')

    if df[variavel].nunique() <= 10:
        plt.figure(figsize=(8, 4))
        sns.countplot(y=variavel, data=df, palette='viridis')
        plt.title(f'Distribuição de {variavel}')
        plt.show()
# Out:
# Variável: SEXO
# Categorias Únicas: ['Masculino' 'Feminino' 'Prefiro não dizer' 'Outro']
# Tabela de Frequência:
# Feminino             508
# Masculino            361
# Prefiro não dizer     10
# Outro                  3
# Name: SEXO, dtype: int64
# <ipython-input-30-b4789b81d0c0>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=variavel, data=df, palette='viridis')
# Variável: QUANTAS PESSOAS MORAM COM VOCÊ
# Categorias Únicas: ['5 ou mais' 3 4 2 1 0]
# Tabela de Frequência:
# 3            256
# 4            213
# 2            186
# 5 ou mais    148
# 1             63
# 0             16
# Name: QUANTAS PESSOAS MORAM COM VOCÊ, dtype: int64
# <ipython-input-30-b4789b81d0c0>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=variavel, data=df, palette='viridis')
# Variável: RENDA/FAMILIA
# Categorias Únicas: ['Até 1 salário mínimo' 'Prefiro não responder'
#  'De 7 a 10 salários mínimos' 'De 3 a 6 salários mínimos'
#  'De 1 a 2 salários mínimos' 'Acima de 10 salários mínimos']
# Tabela de Frequência:
# De 1 a 2 salários mínimos       330
# De 3 a 6 salários mínimos       261
# Até 1 salário mínimo            155
# Prefiro não responder            70
# De 7 a 10 salários mínimos       45
# Acima de 10 salários mínimos     21
# Name: RENDA/FAMILIA, dtype: int64
# <ipython-input-30-b4789b81d0c0>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=variavel, data=df, palette='viridis')
# Variável: ESCOLARIDADE/PAIS
# Categorias Únicas: ['Nível Médio (1º ao 3º ano)' 'Nível Fundamental (1º ao 9º ano)'
#  'Não sei responder' 'Nível superior' 'Analfabeto']
# Tabela de Frequência:
# Nível Médio (1º ao 3º ano)          383
# Nível superior                      263
# Nível Fundamental (1º ao 9º ano)    166
# Não sei responder                    41
# Analfabeto                           29
# Name: ESCOLARIDADE/PAIS, dtype: int64
# <ipython-input-30-b4789b81d0c0>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=variavel, data=df, palette='viridis')
# Variável: ESTADO CIVIL
# Categorias Únicas: ['Solteiro (a)' 'Casado (a)' 'Divorciado (a)' 'Viúvo (a)']
# Tabela de Frequência:
# Solteiro (a)      843
# Casado (a)         31
# Divorciado (a)      7
# Viúvo (a)           1
# Name: ESTADO CIVIL, dtype: int64
# <ipython-input-30-b4789b81d0c0>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=variavel, data=df, palette='viridis')
# Variável: QUANTOS FILHOS
# Categorias Únicas: [0 3 2 1 4 '5 ou mais']
# Tabela de Frequência:
# 0            827
# 1             25
# 2             15
# 3              8
# 4              6
# 5 ou mais      1
# Name: QUANTOS FILHOS, dtype: int64
# <ipython-input-30-b4789b81d0c0>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=variavel, data=df, palette='viridis')
# Variável: TRABALHA
# Categorias Únicas: ['Não' 'Sim']
# Tabela de Frequência:
# Não    540
# Sim    342
# Name: TRABALHA, dtype: int64
# <ipython-input-30-b4789b81d0c0>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=variavel, data=df, palette='viridis')
# Variável: RAÇA
# Categorias Únicas: ['Parda' 'Preta' 'Branca' 'Indígena' 'Amarela']
# Tabela de Frequência:
# Branca      353
# Parda       344
# Preta       149
# Amarela      27
# Indígena      9
# Name: RAÇA, dtype: int64
# <ipython-input-30-b4789b81d0c0>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=variavel, data=df, palette='viridis')
# Variável: TIPO DE ESCOLA
# Categorias Únicas: ['Pública' 'Particular' 'Outros']
# Tabela de Frequência:
# Pública       754
# Particular     99
# Outros         29
# Name: TIPO DE ESCOLA, dtype: int64
# <ipython-input-30-b4789b81d0c0>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=variavel, data=df, palette='viridis')
# Variável: CURSO DE INTERESSE
# Categorias Únicas: ['Faculdade de Engenharia Civil' 'Faculdade de Educação Física'
#  'Faculdade de Direito'
#  'Faculdade de Psicologia, Faculdade de Administração, Faculdade de Ciências Econômicas, Faculdade de Ciência Da Computação'
#  'Faculdade de Ciência Da Computação'
#  'Faculdade de Psicologia, Faculdade de Administração'
#  'Faculdade de Educação Física, Gestão da Tecnologia da Informação, Análise e Desenvolvimento de Sistemas'
#  'Faculdade de Pedagogia, Faculdade de Educação Física, Curso de Gastronomia, Faculdade de Publicidade e Propaganda, Faculdade de Jornalismo, Curso de Design Gráfico'
#  'Faculdade de Veterinária, Faculdade de Direito' 'Outro'
#  'Gestão da Tecnologia da Informação' 'Faculdade de Ciências Econômicas'
#  'Faculdade de Odontologia' 'Análise e Desenvolvimento de Sistemas'
#  'Faculdade de Pedagogia, Curso de Design Gráfico'
#  'Faculdade de Veterinária'
#  'Faculdade de Odontologia, Faculdade de Fisioterapia'
#  'Faculdade de Administração' 'Não sei'
#  'Faculdade de Fisioterapia, Faculdade de Nutrição'
#  'Faculdade de Enfermagem'
FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=variavel, data=df, palette='viridis')
# Variável: GASTO COM INTERNET DIÁRIO
# Categorias Únicas: ['De 3 a 4 horas' 'De 2 a 3 horas' 'Mais de 4 horas' 'De 1 a 2 horas'
#  'Até 1 hora']
# Tabela de Frequência:
# Mais de 4 horas    411
# De 2 a 3 horas     171
# De 3 a 4 horas     143
# De 1 a 2 horas     116
# Até 1 hora          41
# Name: GASTO COM INTERNET DIÁRIO, dtype: int64
# <ipython-input-30-b4789b81d0c0>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=variavel, data=df, palette='viridis')
# Variável: VOCÊ ESTUDARIA NESSA FACULDADE
# Categorias Únicas: ['Não' 'Talvez' 'Sim']
# Tabela de Frequência:
# Sim       617
# Talvez    183
# Não        82
# Name: VOCÊ ESTUDARIA NESSA FACULDADE, dtype: int64
# <ipython-input-30-b4789b81d0c0>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=variavel, data=df, palette='viridis')

# %%
top_cursos = df['CURSO DE INTERESSE'].value_counts().head(20)


plt.figure(figsize=(10, 6))
sns.barplot(x=top_cursos.values, y=top_cursos.index, palette='viridis')
plt.title('Top 20 Cursos de Interesse')
plt.xlabel('Número de Respostas')
plt.ylabel('Curso')
plt.show()
# Out:
# <ipython-input-33-7874a93a1e82>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_cursos.values, y=top_cursos.index, palette='viridis')

# %%
top_cursos_masculinos = df[df['SEXO'] == 'Masculino']['CURSO DE INTERESSE'].value_counts().head(20)
top_cursos_femininos = df[df['SEXO'] == 'Feminino']['CURSO DE INTERESSE'].value_counts().head(20)


plt.figure(figsize=(10, 6))
sns.barplot(x=top_cursos_masculinos.values, y=top_cursos_masculinos.index, palette='viridis')
plt.title('Top 20 Cursos de Interesse para Homens')
plt.xlabel('Número de Respostas')
plt.ylabel('Curso')
plt.show()


plt.figure(figsize=(10, 6))
sns.barplot(x=top_cursos_femininos.values, y=top_cursos_femininos.index, palette='viridis')
plt.title('Top 20 Cursos de Interesse para Mulheres')
plt.xlabel('Número de Respostas')
plt.ylabel('Curso')
plt.show()
# Out:
# <ipython-input-34-2d28fd094e08>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_cursos_masculinos.values, y=top_cursos_masculinos.index, palette='viridis')
# <ipython-input-34-2d28fd094e08>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_cursos_femininos.values, y=top_cursos_femininos.index, palette='viridis')

# %% [markdown]
# ## ANALISE BIVARIADA
#
# ---

# %%
tab = pd.crosstab(df['SEXO'], df['ESTADO CIVIL'], margins= True)
tab
# Out:
# ESTADO CIVIL       Casado (a)  Divorciado (a)  Solteiro (a)  Viúvo (a)  All
# SEXO
# Feminino                   19               4           485          0  508
# Masculino                  12               3           345          1  361
# Outro                       0               0             3          0    3
# Prefiro não dizer           0               0            10          0   10
# All                        31               7           843          1  882

# %%
df_tab = df.groupby('SEXO')['ESTADO CIVIL'].value_counts().unstack()
df_tab.plot(kind='barh', stacked=True)
plt.show()

# %%
tab = pd.crosstab(df['SEXO'], df['TRABALHA'], margins= True)
tab
# Out:
# TRABALHA           Não  Sim  All
# SEXO
# Feminino           333  175  508
# Masculino          197  164  361
# Outro                3    0    3
# Prefiro não dizer    7    3   10
# All                540  342  882

# %%
df_tab = df.groupby('SEXO')['TRABALHA'].value_counts().unstack()

df_tab.plot(kind='bar', stacked=True  )

plt.show()
